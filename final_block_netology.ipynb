# %% [markdown]
# <a href="https://colab.research.google.com/github/barryinvisible/test/blob/main/final_block_netology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Загрузите файл HR.csv в pandas dataframe

# %%
df = pd.read_csv('/content/HR.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# # 2. Рассчитайте основные статистики для переменных

# %%
df['satisfaction_level'].mean()
# Out:
# 0.6128335222348156

# %%
df['satisfaction_level'].median()
# Out:
# 0.64

# %%
df['satisfaction_level'].mode()
# Out:
# 0    0.1
# Name: satisfaction_level, dtype: float64

# %%
df['satisfaction_level'].min()
# Out:
# 0.09

# %%
df['satisfaction_level'].max()
# Out:
# 1.0

# %%
df['satisfaction_level'].std()
# Out:
# 0.24863065106114257

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# # 3. Рассчитайте и визуализировать корреляционную матрицу для количественных переменных. Определите две самые скоррелированные и две наименее скоррелированные переменные.

# %%
df_corr = df[['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company','Work_accident','left','promotion_last_5years']]
df_corr.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0

# %%
df_corr.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
# самые скоррелированные average_montly_hours и number_project, last_evaluation и number_project
# самые не скоррелированные left и satisfaction_level, left и Work_accident
sns.set(rc={'figure.figsize':(9,7)})
sns.heatmap(df_corr.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 4. Рассчитайте сколько сотрудников работает в каждом департаменте.

# %%
df['department'].value_counts()
# Out:
# department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %% [markdown]
# # 5. Показать распределение сотрудников по зарплатам.

# %%
df['salary'].value_counts()
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %%
df.groupby('salary')['salary'].count().plot(kind="barh")
# Out:
# <Axes: ylabel='salary'>

# %%
ax = sns.countplot(data=df, x='salary')
ax.bar_label(ax.containers[0])
plt.title('Зарплата')
plt.ylabel('Количество сотрудников')
plt.show()

# %%
sns.histplot(df, x='salary', hue='department', element='step', stat='density')
plt.title('Распределение зарплаты по департаментам')
plt.show()

# %% [markdown]
# # 6. Показать распределение сотрудников по зарплатам в каждом департаменте по отдельности

# %%
# рассмотреть каждый департамент по отдельности
sns.histplot(df[df['department'] == 'IT'], x='salary', hue='department', element='step', stat='density')
plt.title('Распределение зарплаты по департаменту IT')
plt.show()

# %%
sns.histplot(df[df['department'] == 'sales'], x='salary', hue='department', element='step', stat='density')
plt.title('Распределение зарплаты по департаменту sales')
plt.show()

# %%
# смотрим все департаменты
df.groupby([df['department'],df['salary']])[['salary']].count()
# Out:
#                     salary
# department  salary
# IT          high        83
#             low        609
#             medium     535
# RandD       high        51
#             low        364
#             medium     372
# accounting  high        74
#             low        358
#             medium     335
# hr          high        45
#             low        335
#             medium     359
# management  high       225
#             low        180
#             medium     225
# marketing   high        80
#             low        402
#             medium     376
# product_mng high        68
#             low        451
#             medium     383
# sales       high       269
#             low       2099
#             medium    1772
# support     high       141
#             low       1146
#             medium     942
# technical   high       201
#             low       1372
#             medium    1147

# %% [markdown]
# # 7. Проверить гипотезу, что сотрудники с высоким окладом проводят на работе больше времени, чем сотрудники с низким окладом

# %%
df_high = list(df.loc[df['salary'] == 'high']['average_montly_hours'])

# %%
df_low = list(df.loc[df['salary'] == 'low']['average_montly_hours'])

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
# разницы почти нет
plt.hist(df_high, bins=100, density=True);
plt.hist(df_low, bins=100, density=True);

# %% [markdown]
# # 8. Рассчитать следующие показатели среди уволившихся и неуволившихся сотрудников (по отдельности):
#
# * Доля сотрудников с повышением за последние 5 лет
#
# * Средняя степень удовлетворенности
#
# * Среднее количество проектов

# %%
df_left = df[df['left'] == 1]
df_left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
#  Доля сотрудников с повышением за последние 5 лет среди уволившихся
len(df_left[df_left['promotion_last_5years'] == 1])/len(df_left)
# Out:
# 0.005320638476617194

# %%
# Средняя степень удовлетворенности среди уволившихся
df_left['satisfaction_level'].mean()
# Out:
# 0.4400980117614114

# %%
# Среднее количество проектов среди уволившихся
df_left['number_project'].mean()
# Out:
# 3.8555026603192384

# %%
df_noleft = df[df['left'] == 0]
df_noleft
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# ...                   ...              ...             ...
# 14206                0.90             0.55               3
# 14207                0.74             0.95               5
# 14208                0.85             0.54               3
# 14209                0.33             0.65               3
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2000                    215                   3              0     0
# 2001                    202                   3              0     0
# ...

# %%
#  Доля сотрудников с повышением за последние 5 лет среди оставшихся
len(df_noleft[df_noleft['promotion_last_5years'] == 1])/len(df_left)
# Out:
# 0.08401008120974517

# %%
# Средняя степень удовлетворенности среди оставшихся
df_noleft['satisfaction_level'].mean()
# Out:
# 0.666809590479524

# %%
# Среднее количество проектов среди оставшихся
df_noleft['number_project'].mean()
# Out:
# 3.786664333216661
